# %%
import gym_FPS
import gym
import random
from gym_FPS.utils import *
import time
import random
import numpy as np
env=gym.make('FPSDemo-v2')
env.set_env(client_DEBUG=False,env_DEBUG=False,SEVERIP='127.0.0.1',SERVERPORT=5123)

# %%
#init env
print('aaaaaaaaaaaaaaaaaaaaa')
#feature=env.get_feature() #features
#print(feature)

#action get by you"
#stepaction=env.transfer(action) #action transfer
"stepaction update"
#env.step(stepaction)
win=0
for i in range(50):
    env.reset() 
    while True:
        var=env.get_feature()
        #print(var['gameover'])
        if var['gameover']:
            if var['win']==0:
                win+=1
            break
        time.sleep(2)
        env.enemyai()
print('cur win rate is %d' % win)
# Out:
# aaaaaaaaaaaaaaaaaaaaa
# received time out!
# Exception in thread Thread-6:
# Traceback (most recent call last):
#   File "C:\Program Files\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Program Files\Anaconda3\lib\threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "G:\qjh\20161028 无人机\20171030FPS\code\fps\gym_FPS\envs\FPS_env.py", line 105, in get_game_variable
#     objid_list = get_simple_id_list(self.get_objid_list().keys())
#   File "G:\qjh\20161028 无人机\20171030FPS\code\fps\gym_FPS\envs\FPS_env.py", line 90, in get_objid_list
#     s = self.client2.receive().split('`')
# AttributeError: 'NoneType' object has no attribute 'split'
# received time out!
# send failed!!!!!!!!!!!!!!!!!!
# received time out!
# send failed!!!!!!!!!!!!!!!!!!
# received time out!
# send failed!!!!!!!!!!!!!!!!!!
# received time out!
# send failed!!!!!!!!!!!!!!!!!!
# received time out!
# send failed!!!!!!!!!!!!!!!!!!
# ...

# %%
env.states
# Out:
# {0: {'ANGLE': 106.4138,
#   'DEAD': 0.0,
#   'HEALTH': 100.0,
#   'KILLCOUNT': 0.0,
#   'LAST_POSITION': [-212.8477, 0.4025051, 17.45391],
#   'PITCH': 0.0,
#   'PLAYER_NUMBER': 0.0,
#   'POSITION': [-212.2309, 0.351009, 17.27109],
#   'TEAM_ID': 1.0},
#  1: {'ANGLE': 143.8893,
#   'DEAD': 0.0,
#   'HEALTH': 100.0,
#   'KILLCOUNT': 0.0,
#   'LAST_POSITION': [-242.4625, -0.9808033, 61.09315],
#   'PITCH': 0.0,
#   'PLAYER_NUMBER': 1.0,
#   'POSITION': [-242.4625, -0.9808033, 61.09315],
#   'TEAM_ID': -1.0},
#  2: {'ANGLE': 135.796,
#   'DEAD': 0.0,
#   'HEALTH': 100.0,
#   'KILLCOUNT': 0.0,
#   'LAST_POSITION': [-245.2186, -1.383329, 61.21755],
#   'PITCH': 0.0,
#   'PLAYER_NUMBER': 2.0,
#   'POSITION': [-245.2186, -1.383329, 61.21755],
#   'TEAM_ID': -1.0},
#  3: {'ANGLE': 155.0667,
#   'DEAD': 0.0,
#   'HEALTH': 100.0,
#   'KILLCOUNT': 0.0,
#   'LAST_POSITION': [-240.4945, -0.5963978, 63.04615],
#   'PITCH': 0.0,
#   'PLAYER_NUMBER': 3.0,
# ...
